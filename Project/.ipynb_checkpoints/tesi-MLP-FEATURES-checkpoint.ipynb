# %% [markdown]
# # Classificazione mood tramite features canzone

# %%
import zipfile
import os
import pandas as pd
import tensorflow as tf
from tensorflow import keras
from keras import optimizers
from keras import layers
from keras.regularizers import l1
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
from keras.models import Sequential
from keras.layers import Dense, GlobalAveragePooling2D, Dropout, Flatten, concatenate
from tensorflow.keras import regularizers
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.utils.vis_utils import plot_model
import pylab as pl
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from keras.utils import np_utils
from sklearn import preprocessing

# audio lib
import librosa
import IPython.display as ipd

# %% [markdown]
# ## Analisi Esplorativa
#
# Si importa il primo dataset su cui si andrà ad effettuare l'addestramento della rete

# %%
path = '../input/PMEmo2019'
features = pd.read_csv(path + '/features/static_features.csv')
features.set_index('musicId', inplace=True)
features.shape
# Out:
# (794, 6373)

# %% [markdown]
# Il dataset è composto da 794 canzoni. Per ogni canzone sono memorizzate 6373 features estratte dal software OPENSMILE.

# %%
features
# Out:
#          audspec_lengthL1norm_sma_range  audspec_lengthL1norm_sma_maxPos  \
# musicId
# 1                              7.318236                         0.716432
# 4                              6.558082                         0.703399
# 5                              8.152512                         0.368032
# 6                              8.527122                         0.281728
# 7                              7.756963                         0.958923
# ...                                 ...                              ...
# 993                            8.378412                         0.680590
# 996                            7.961765                         0.923569
# 997                            8.305466                         0.461791
# 999                            8.302629                         0.760462
# 1000                           8.363514                         0.244803
#
#          audspec_lengthL1norm_sma_minPos  audspec_lengthL1norm_sma_quartile1  \
# musicId
# 1                                    0.0                            2.245124
# 4                                    0.0                            1.606873
# 5                                    0.0                            1.404577
# 6                                    0.0                            2.106767
# 7                                    0.0                            3.683783
# ...                                  ...                                 ...
# 993                                  0.0                            2.728126
# 996                                  0.0                            3.891528
# 997                                  0.0                            2.562763
# 999                                  0.0                            4.225634
# 1000                                 0.0                            5.116090
#
#          audspec_lengthL1norm_sma_quartile2  \
# musicId
# 1                                  3.145057
# 4                                  2.116417
# 5                                  1.969597
# 6                                  3.345879
# 7                                  4.581017
# ...                                     ...
# 993                                3.845191
# 996                                5.317545
# 997                                4.783508
# 999                                5.345556
# 1000                               5.982607
#
#          audspec_lengthL1norm_sma_quartile3  audspec_lengthL1norm_sma_iqr1-2  \
# musicId
# 1                                  3.956726                         0.899933
# 4                                  2.917487                         0.509543
# 5                                  2.666271                         0.565020
# 6                                  4.250905                         1.239112
# 7                                  5.297434                         0.897234
# ...                                     ...                              ...
# 993                                5.264757                         1.117064
# 996                                5.944809                         1.426017
# 997                                5.864176                         2.220744
# 999                                6.034480                         1.119922
# 1000                               6.588160                         0.866517
#
#          audspec_lengthL1norm_sma_iqr2-3  audspec_lengthL1norm_sma_iqr1-3  \
# musicId
# 1                               0.811669                         1.711601
# 4                               0.801071                         1.310614
# 5                               0.696674                         1.261694
# 6                               0.905025                         2.144137
# 7                               0.716417                         1.613651
# ...                                  ...                              ...
# 993                             1.419566                         2.536630
# 996                             0.627264                         2.053281
# 997                             1.080668                         3.301413
# 999                             0.688924                         1.808846
# 1000                            0.605553                         1.472070
#
#          audspec_lengthL1norm_sma_percentile1.0  ...  \
# musicId                                          ...
# 1                                      0.929235  ...
# 4                                      0.311745  ...
# 5                                      0.507137  ...
# 6                                      0.211913  ...
# 7                                      1.357028  ...
# ...                                         ...  ...
# 993                                    1.211291  ...
# 996                                    0.019338  ...
# 997                                    0.010031  ...
# 999                                    0.012528  ...
# 1000                                   0.018069  ...
#
#          mfcc_sma_de[14]_peakRangeAbs  mfcc_sma_de[14]_peakRangeRel  \
# musicId
# 1                           10.694290                      0.552123
# 4                            8.273178                      0.535849
# 5                            9.705502                      0.598316
# 6                            7.689778                      0.575360
# 7                            8.710414                      0.560565
# ...                               ...                           ...
# 993                         11.226420                      0.559879
# 996                         12.711770                      0.639621
# 997                          8.825824                      0.554743
# 999                          7.450211                      0.499976
# 1000                         8.164929                      0.474324
#
#          mfcc_sma_de[14]_peakMeanAbs  mfcc_sma_de[14]_peakMeanMeanDist  \
# musicId
# 1                           2.884782                          2.886936
# 4                           2.659783                          2.660821
# 5                           2.422745                          2.421824
# 6                           2.224280                          2.224137
# 7                           2.219199                          2.227387
# ...                              ...                               ...
# 993                         2.544755                          2.546021
# 996                         2.599786                          2.598629
# 997                         2.225728                          2.223910
# 999                         2.244456                          2.243278
# 1000                        2.249026                          2.247108
#
#          mfcc_sma_de[14]_peakMeanRel  mfcc_sma_de[14]_minRangeRel  \
# musicId
# 1                         -1339.0630                     0.554930
# 4                         -2561.7130                     0.665665
# 5                          2630.3710                     0.550189
# 6                         15484.8700                     0.580155
# 7                          -271.0219                     0.536837
# ...                              ...                          ...
# 993                       -2010.1450                     0.622314
# 996                        2247.9420                     0.545877
# 997                        1224.7670                     0.579119
# 999                        1906.0100                     0.580830
# 1000                       1172.5540                     0.573543
#
#          mfcc_sma_de[14]_meanRisingSlope  mfcc_sma_de[14]_stddevRisingSlope  \
# musicId
# 1                              113.55350                           57.37954
# 4                              104.48770                           63.52283
# 5                              105.54060                           53.73272
# 6                               98.76061                           49.21307
# 7                               96.05625                           51.72694
# ...                                  ...                                ...
# 993                            109.22900                           59.13757
# 996                            113.89870                           60.04008
# 997                            104.00700                           50.69448
# 999                             97.37801                           48.68456
# 1000                            98.06568                           50.81982
#
#          mfcc_sma_de[14]_meanFallingSlope  mfcc_sma_de[14]_stddevFallingSlope
# musicId
# 1                               111.61330                            59.35901
# 4                               106.18320                            54.71746
# 5                               105.51670                            54.68540
# 6                               101.23990                            49.36958
# 7                                95.41311                            53.10697
# ...                                   ...                                 ...
# 993                             105.51910                            58.49892
# 996                             114.09210                            55.47742
# 997                             101.76250                            55.04704
# 999                              98.12227                            48.16222
# 1000                             95.18258                            50.26721
#
# [794 rows x 6373 columns]

# %%
example_mp3 = '../input/PMEmo2019/chorus/945.mp3'
ipd.Audio(example_mp3)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Si osservano le annotazioni: sono definite in base alla media delle singole annotazioni effettuate dagli utenti sul livello di arousal e valence.

# %%
annotations = pd.read_csv(path + '/annotations/static_annotations.csv')
annotations.set_index('musicId', inplace=True)
annotations.shape
# Out:
# (767, 2)

# %%
annotations.head()
# Out:
#          Arousal(mean)  Valence(mean)
# musicId
# 1               0.4000         0.5750
# 4               0.2625         0.2875
# 5               0.1500         0.2000
# 6               0.5125         0.3500
# 7               0.7000         0.7250

# %%
din_annotations = pd.read_csv(path + '/annotations/dynamic_annotations.csv')

din_annotations.shape
# Out:
# (36434, 4)

# %% [markdown]
# Mancano delle canzoni (794 vs 767), provo a vedere se è causa di un errore nel calcolo della media o mancano delle annotazioni. Eseguo il calcolo della media dalle annotazioni row.

# %%
mean_Arousal = din_annotations.groupby('musicId')['Arousal(mean)'].mean()

mean_Arousal.shape
# Out:
# (767,)

# %% [markdown]
# Il numero di canzoni è uguale al csv static_annotations quindi mancano delle annotazioni riferite a delle canzoni. Cerco gli indici mancanti.

# %%
diff_index = features.index.difference(annotations.index)

diff_index
# Out:
# Int64Index([ 11,  64,  85,  95, 101, 110, 118, 205, 206, 226, 264, 278, 291,
#             311, 320, 352, 359, 371, 384, 392, 404, 459, 464, 596, 610, 687,
#             866],
#            dtype='int64', name='musicId')

# %% [markdown]
# Rimuovo dalle features le canzoni con gli indici di cui mancano le annotazioni.

# %%
features.drop(diff_index, axis=0, inplace=True)


features.shape
# Out:
# (767, 6373)

# %%
labels = []

annotations = annotations.reset_index() 
for index, row in annotations.iterrows():
    if row[1] <= 0.5 and row[2] <= 0.5:
        labels.append(0) #LL
    elif  row[1] <= 0.5 and row[2] > 0.5:
            labels.append(1) #LW
    elif  row[1] > 0.5 and row[2] <= 0.5:
            labels.append(2) #HL
    elif  row[1] > 0.5 and row[2] > 0.5:
            labels.append(3) #HH

# %%
len(labels)
# Out:
# 767

# %%
Y = np.array(labels)

unique, counts = np.unique(Y, return_counts=True)

print(np.asarray((unique, counts)).T)


pos  = np.arange(len(unique))
width = 1.0    
ax = plt.axes()
ax.set_xticks(pos)
ax.set_xticklabels(unique)

plt.bar(pos, counts, width, color = ['r','b','g','y'])
plt.show()
# Out:
# [[  0 138]
#  [  1  62]
#  [  2  76]
#  [  3 491]]

# %% [markdown]
# Il dataset risulta sbilanciato rispetto a canzoni con A+ V+.
# Si procede a scalare i valori per effettuare la classificazione.

# %%
features = features.to_numpy()
scaler = preprocessing.MinMaxScaler()
scaler.fit(features)

features_scaled = scaler.transform(features)

features_scaled[0]
# Out:
# array([0.56109149, 0.70730004, 0.        , ..., 0.41773809, 0.43956664,
#        0.41690514])

# %% [markdown]
# # Fully-Connected Neural Network

# %%
x_train, x_test, y_train, y_test = train_test_split(features_scaled, Y, test_size=0.1)

y_train =  np_utils.to_categorical(y_train)
y_test =  np_utils.to_categorical(y_test)

print(x_test.shape, y_test.shape)
# Out:
# (77, 6373) (77, 4)

# %%
dims = x_train.shape[1]
nb_classes = 4

mlp = Sequential()
mlp.add(Dense(2048, activation='relu', input_shape=(dims,),kernel_regularizer=l1(0.001)))
mlp.add(Dropout(0.5))
mlp.add(Dense(1024, activation='relu',kernel_regularizer=l1(0.001)))
mlp.add(Dropout(0.4))
mlp.add(Dense(512, activation='relu',kernel_regularizer=l1(0.001)))
mlp.add(Dropout(0.3))
mlp.add(Dense(64, activation='relu',kernel_regularizer=l1(0.001)))
mlp.add(Dropout(0.2))
mlp.add(Dense(4, activation = "softmax"))


# compile: optimizer & losses/metrics
mlp.compile(loss='categorical_crossentropy', optimizer='sgd',metrics=['accuracy'])
mlp.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 2048)              13053952
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                32832
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 15,710,020
# Trainable params: 15,710,020
# Non-trainable params: 0
# _________________________________________________________________
# 2022-04-28 21:51:20.068943: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
filepath_mlp="weights.mlp.hdf5"
checkpoint = ModelCheckpoint(filepath_mlp, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# %%
model_history = mlp.fit(x_train, y_train, batch_size=16, 
                        epochs=300, verbose=0, validation_split = 0.1,
                        callbacks=[checkpoint])

mlp.load_weights(filepath_mlp)
# Out:
# 2022-04-28 21:51:20.876925: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 00001: val_loss improved from inf to 233.62776, saving model to weights.mlp.hdf5
#
# Epoch 00002: val_loss improved from 233.62776 to 227.61258, saving model to weights.mlp.hdf5
#
# Epoch 00003: val_loss improved from 227.61258 to 221.69487, saving model to weights.mlp.hdf5
#
# Epoch 00004: val_loss improved from 221.69487 to 215.91713, saving model to weights.mlp.hdf5
#
# Epoch 00005: val_loss improved from 215.91713 to 210.09935, saving model to weights.mlp.hdf5
#
# Epoch 00006: val_loss improved from 210.09935 to 204.39401, saving model to weights.mlp.hdf5
#
# Epoch 00007: val_loss improved from 204.39401 to 198.86063, saving model to weights.mlp.hdf5
#
# Epoch 00008: val_loss improved from 198.86063 to 193.28203, saving model to weights.mlp.hdf5
#
# Epoch 00009: val_loss improved from 193.28203 to 187.88365, saving model to weights.mlp.hdf5
#
# Epoch 00010: val_loss improved from 187.88365 to 182.51636, saving model to weights.mlp.hdf5
#
# Epoch 00011: val_loss improved from 182.51636 to 177.31531, saving model to weights.mlp.hdf5
#
# Epoch 00012: val_loss improved from 177.31531 to 172.08865, saving model to weights.mlp.hdf5
#
# Epoch 00013: val_loss improved from 172.08865 to 167.07709, saving model to weights.mlp.hdf5
#
# Epoch 00014: val_loss improved from 167.07709 to 162.08014, saving model to weights.mlp.hdf5
#
# Epoch 00015: val_loss improved from 162.08014 to 157.06105, saving model to weights.mlp.hdf5
#
# Epoch 00016: val_loss improved from 157.06105 to 152.21222, saving model to weights.mlp.hdf5
#
# Epoch 00017: val_loss improved from 152.21222 to 147.66757, saving model to weights.mlp.hdf5
#
# Epoch 00018: val_loss improved from 147.66757 to 142.92638, saving model to weights.mlp.hdf5
#
# Epoch 00019: val_loss improved from 142.92638 to 138.26938, saving model to weights.mlp.hdf5
#
# Epoch 00020: val_loss improved from 138.26938 to 133.68584, saving model to weights.mlp.hdf5
#
# Epoch 00021: val_loss improved from 133.68584 to 129.35672, saving model to weights.mlp.hdf5
#
# Epoch 00022: val_loss improved from 129.35672 to 124.93102, saving model to weights.mlp.hdf5
#
# Epoch 00023: val_loss improved from 124.93102 to 120.66684, saving model to weights.mlp.hdf5
#
# Epoch 00024: val_loss improved from 120.66684 to 116.50002, saving model to weights.mlp.hdf5
#
# Epoch 00025: val_loss improved from 116.50002 to 112.70233, saving model to weights.mlp.hdf5
#
# Epoch 00026: val_loss improved from 112.70233 to 108.45251, saving model to weights.mlp.hdf5
#
# Epoch 00027: val_loss improved from 108.45251 to 104.59669, saving model to weights.mlp.hdf5
#
# Epoch 00028: val_loss improved from 104.59669 to 100.66006, saving model to weights.mlp.hdf5
#
# Epoch 00029: val_loss improved from 100.66006 to 96.88149, saving model to weights.mlp.hdf5
#
# Epoch 00030: val_loss improved from 96.88149 to 93.34428, saving model to weights.mlp.hdf5
#
# Epoch 00031: val_loss improved from 93.34428 to 89.64513, saving model to weights.mlp.hdf5
#
# Epoch 00032: val_loss improved from 89.64513 to 86.17689, saving model to weights.mlp.hdf5
#
# Epoch 00033: val_loss improved from 86.17689 to 82.81679, saving model to weights.mlp.hdf5
#
# Epoch 00034: val_loss improved from 82.81679 to 79.75005, saving model to weights.mlp.hdf5
#
# Epoch 00035: val_loss improved from 79.75005 to 76.14382, saving model to weights.mlp.hdf5
#
# Epoch 00036: val_loss improved from 76.14382 to 72.96426, saving model to weights.mlp.hdf5
#
# Epoch 00037: val_loss improved from 72.96426 to 70.01572, saving model to weights.mlp.hdf5
#
# Epoch 00038: val_loss improved from 70.01572 to 67.02847, saving model to weights.mlp.hdf5
#
# Epoch 00039: val_loss improved from 67.02847 to 64.06145, saving model to weights.mlp.hdf5
#
# Epoch 00040: val_loss improved from 64.06145 to 61.41868, saving model to weights.mlp.hdf5
#
# Epoch 00041: val_loss improved from 61.41868 to 58.29831, saving model to weights.mlp.hdf5
#
# Epoch 00042: val_loss improved from 58.29831 to 55.67034, saving model to weights.mlp.hdf5
#
# Epoch 00043: val_loss improved from 55.67034 to 53.26807, saving model to weights.mlp.hdf5
#
# Epoch 00044: val_loss improved from 53.26807 to 50.58772, saving model to weights.mlp.hdf5
#
# Epoch 00045: val_loss improved from 50.58772 to 48.18285, saving model to weights.mlp.hdf5
#
# Epoch 00046: val_loss improved from 48.18285 to 45.80727, saving model to weights.mlp.hdf5
#
# Epoch 00047: val_loss improved from 45.80727 to 43.51619, saving model to weights.mlp.hdf5
#
# Epoch 00048: val_loss improved from 43.51619 to 41.33709, saving model to weights.mlp.hdf5
#
# Epoch 00049: val_loss improved from 41.33709 to 39.26606, saving model to weights.mlp.hdf5
#
# Epoch 00050: val_loss improved from 39.26606 to 37.53825, saving model to weights.mlp.hdf5
#
# Epoch 00051: val_loss improved from 37.53825 to 35.39742, saving model to weights.mlp.hdf5
#
# Epoch 00052: val_loss improved from 35.39742 to 33.53245, saving model to weights.mlp.hdf5
#
# Epoch 00053: val_loss improved from 33.53245 to 31.69750, saving model to weights.mlp.hdf5
#
# Epoch 00054: val_loss improved from 31.69750 to 30.09940, saving model to weights.mlp.hdf5
#
# Epoch 00055: val_loss improved from 30.09940 to 28.47973, saving model to weights.mlp.hdf5
#
# Epoch 00056: val_loss improved from 28.47973 to 26.93168, saving model to weights.mlp.hdf5
#
# Epoch 00057: val_loss improved from 26.93168 to 25.90117, saving model to weights.mlp.hdf5
#
# Epoch 00058: val_loss improved from 25.90117 to 24.24232, saving model to weights.mlp.hdf5
#
# Epoch 00059: val_loss improved from 24.24232 to 23.03498, saving model to weights.mlp.hdf5
#
# Epoch 00060: val_loss improved from 23.03498 to 21.72164, saving model to weights.mlp.hdf5
#
# Epoch 00061: val_loss improved from 21.72164 to 20.83838, saving model to weights.mlp.hdf5
#
# Epoch 00062: val_loss improved from 20.83838 to 20.14700, saving model to weights.mlp.hdf5
#
# Epoch 00063: val_loss improved from 20.14700 to 18.84376, saving model to weights.mlp.hdf5
#
# Epoch 00064: val_loss improved from 18.84376 to 18.03475, saving model to weights.mlp.hdf5
#
# Epoch 00065: val_loss improved from 18.03475 to 17.25382, saving model to weights.mlp.hdf5
#
# Epoch 00066: val_loss improved from 17.25382 to 16.47253, saving model to weights.mlp.hdf5
#
# Epoch 00067: val_loss improved from 16.47253 to 15.82534, saving model to weights.mlp.hdf5
#
# Epoch 00068: val_loss improved from 15.82534 to 15.23447, saving model to weights.mlp.hdf5
#
# Epoch 00069: val_loss improved from 15.23447 to 14.93252, saving model to weights.mlp.hdf5
#
# Epoch 00070: val_loss improved from 14.93252 to 14.42169, saving model to weights.mlp.hdf5
#
# Epoch 00071: val_loss improved from 14.42169 to 13.89747, saving model to weights.mlp.hdf5
#
# Epoch 00072: val_loss improved from 13.89747 to 13.39636, saving model to weights.mlp.hdf5
#
# Epoch 00073: val_loss improved from 13.39636 to 13.02290, saving model to weights.mlp.hdf5
#
# Epoch 00074: val_loss improved from 13.02290 to 12.55350, saving model to weights.mlp.hdf5
#
# Epoch 00075: val_loss improved from 12.55350 to 12.42357, saving model to weights.mlp.hdf5
#
# Epoch 00076: val_loss improved from 12.42357 to 11.68934, saving model to weights.mlp.hdf5
#
# Epoch 00077: val_loss improved from 11.68934 to 11.41879, saving model to weights.mlp.hdf5
#
# Epoch 00078: val_loss improved from 11.41879 to 10.91961, saving model to weights.mlp.hdf5
#
# Epoch 00079: val_loss improved from 10.91961 to 10.56426, saving model to weights.mlp.hdf5
#
# Epoch 00080: val_loss improved from 10.56426 to 10.19997, saving model to weights.mlp.hdf5
#
# Epoch 00081: val_loss improved from 10.19997 to 9.84899, saving model to weights.mlp.hdf5
#
# Epoch 00082: val_loss improved from 9.84899 to 9.69245, saving model to weights.mlp.hdf5
#
# Epoch 00083: val_loss improved from 9.69245 to 9.22088, saving model to weights.mlp.hdf5
#
# Epoch 00084: val_loss improved from 9.22088 to 8.94431, saving model to weights.mlp.hdf5
#
# Epoch 00085: val_loss improved from 8.94431 to 8.51904, saving model to weights.mlp.hdf5
#
# Epoch 00086: val_loss improved from 8.51904 to 8.23251, saving model to weights.mlp.hdf5
#
# Epoch 00087: val_loss improved from 8.23251 to 8.02661, saving model to weights.mlp.hdf5
#
# Epoch 00088: val_loss improved from 8.02661 to 7.80116, saving model to weights.mlp.hdf5
#
# Epoch 00089: val_loss improved from 7.80116 to 7.43826, saving model to weights.mlp.hdf5
#
# Epoch 00090: val_loss improved from 7.43826 to 7.28350, saving model to weights.mlp.hdf5
#
# Epoch 00091: val_loss improved from 7.28350 to 6.84863, saving model to weights.mlp.hdf5
#
# Epoch 00092: val_loss improved from 6.84863 to 6.60722, saving model to weights.mlp.hdf5
#
# Epoch 00093: val_loss improved from 6.60722 to 6.30655, saving model to weights.mlp.hdf5
#
# Epoch 00094: val_loss improved from 6.30655 to 6.08186, saving model to weights.mlp.hdf5
#
# Epoch 00095: val_loss improved from 6.08186 to 5.86179, saving model to weights.mlp.hdf5
#
# Epoch 00096: val_loss improved from 5.86179 to 5.69908, saving model to weights.mlp.hdf5
#
# Epoch 00097: val_loss improved from 5.69908 to 5.53877, saving model to weights.mlp.hdf5
#
# Epoch 00098: val_loss improved from 5.53877 to 5.20792, saving model to weights.mlp.hdf5
#
# Epoch 00099: val_loss did not improve from 5.20792
#
# Epoch 00100: val_loss improved from 5.20792 to 4.81343, saving model to weights.mlp.hdf5
#
# Epoch 00101: val_loss improved from 4.81343 to 4.65502, saving model to weights.mlp.hdf5
#
# Epoch 00102: val_loss improved from 4.65502 to 4.59343, saving model to weights.mlp.hdf5
#
# Epoch 00103: val_loss improved from 4.59343 to 4.36185, saving model to weights.mlp.hdf5
#
# Epoch 00104: val_loss improved from 4.36185 to 4.16289, saving model to weights.mlp.hdf5
#
# Epoch 00105: val_loss improved from 4.16289 to 4.06939, saving model to weights.mlp.hdf5
#
# Epoch 00106: val_loss improved from 4.06939 to 3.87818, saving model to weights.mlp.hdf5
#
# Epoch 00107: val_loss improved from 3.87818 to 3.74976, saving model to weights.mlp.hdf5
#
# Epoch 00108: val_loss improved from 3.74976 to 3.71588, saving model to weights.mlp.hdf5
#
# Epoch 00109: val_loss improved from 3.71588 to 3.50803, saving model to weights.mlp.hdf5
#
# Epoch 00110: val_loss did not improve from 3.50803
#
# Epoch 00111: val_loss improved from 3.50803 to 3.31962, saving model to weights.mlp.hdf5
#
# Epoch 00112: val_loss improved from 3.31962 to 3.30633, saving model to weights.mlp.hdf5
#
# Epoch 00113: val_loss improved from 3.30633 to 3.24311, saving model to weights.mlp.hdf5
#
# Epoch 00114: val_loss improved from 3.24311 to 3.17194, saving model to weights.mlp.hdf5
#
# Epoch 00115: val_loss improved from 3.17194 to 3.14152, saving model to weights.mlp.hdf5
#
# Epoch 00116: val_loss improved from 3.14152 to 3.11764, saving model to weights.mlp.hdf5
#
# Epoch 00117: val_loss improved from 3.11764 to 2.90957, saving model to weights.mlp.hdf5
#
# Epoch 00118: val_loss did not improve from 2.90957
#
# Epoch 00119: val_loss improved from 2.90957 to 2.75801, saving model to weights.mlp.hdf5
#
# Epoch 00120: val_loss improved from 2.75801 to 2.74608, saving model to weights.mlp.hdf5
#
# Epoch 00121: val_loss improved from 2.74608 to 2.66730, saving model to weights.mlp.hdf5
#
# Epoch 00122: val_loss improved from 2.66730 to 2.62233, saving model to weights.mlp.hdf5
#
# Epoch 00123: val_loss improved from 2.62233 to 2.52685, saving model to weights.mlp.hdf5
#
# Epoch 00124: val_loss did not improve from 2.52685
#
# Epoch 00125: val_loss did not improve from 2.52685
#
# Epoch 00126: val_loss improved from 2.52685 to 2.41811, saving model to weights.mlp.hdf5
#
# Epoch 00127: val_loss improved from 2.41811 to 2.37496, saving model to weights.mlp.hdf5
#
# Epoch 00128: val_loss did not improve from 2.37496
#
# Epoch 00129: val_loss improved from 2.37496 to 2.33421, saving model to weights.mlp.hdf5
#
# Epoch 00130: val_loss did not improve from 2.33421
#
# Epoch 00131: val_loss improved from 2.33421 to 2.16498, saving model to weights.mlp.hdf5
#
# Epoch 00132: val_loss improved from 2.16498 to 2.13041, saving model to weights.mlp.hdf5
#
# Epoch 00133: val_loss improved from 2.13041 to 2.11171, saving model to weights.mlp.hdf5
#
# Epoch 00134: val_loss improved from 2.11171 to 2.01920, saving model to weights.mlp.hdf5
#
# Epoch 00135: val_loss improved from 2.01920 to 1.97205, saving model to weights.mlp.hdf5
#
# Epoch 00136: val_loss did not improve from 1.97205
#
# Epoch 00137: val_loss improved from 1.97205 to 1.92456, saving model to weights.mlp.hdf5
#
# Epoch 00138: val_loss did not improve from 1.92456
#
# Epoch 00139: val_loss improved from 1.92456 to 1.92375, saving model to weights.mlp.hdf5
#
# Epoch 00140: val_loss did not improve from 1.92375
#
# Epoch 00141: val_loss improved from 1.92375 to 1.88460, saving model to weights.mlp.hdf5
#
# Epoch 00142: val_loss improved from 1.88460 to 1.73279, saving model to weights.mlp.hdf5
#
# Epoch 00143: val_loss did not improve from 1.73279
#
# Epoch 00144: val_loss improved from 1.73279 to 1.68282, saving model to weights.mlp.hdf5
#
# Epoch 00145: val_loss improved from 1.68282 to 1.65010, saving model to weights.mlp.hdf5
#
# Epoch 00146: val_loss did not improve from 1.65010
#
# Epoch 00147: val_loss did not improve from 1.65010
#
# Epoch 00148: val_loss improved from 1.65010 to 1.61815, saving model to weights.mlp.hdf5
#
# Epoch 00149: val_loss did not improve from 1.61815
#
# Epoch 00150: val_loss improved from 1.61815 to 1.53963, saving model to weights.mlp.hdf5
#
# Epoch 00151: val_loss did not improve from 1.53963
#
# Epoch 00152: val_loss improved from 1.53963 to 1.50192, saving model to weights.mlp.hdf5
#
# Epoch 00153: val_loss did not improve from 1.50192
#
# Epoch 00154: val_loss improved from 1.50192 to 1.46538, saving model to weights.mlp.hdf5
#
# Epoch 00155: val_loss improved from 1.46538 to 1.46040, saving model to weights.mlp.hdf5
#
# Epoch 00156: val_loss improved from 1.46040 to 1.44615, saving model to weights.mlp.hdf5
#
# Epoch 00157: val_loss did not improve from 1.44615
#
# Epoch 00158: val_loss did not improve from 1.44615
#
# Epoch 00159: val_loss did not improve from 1.44615
#
# Epoch 00160: val_loss did not improve from 1.44615
#
# Epoch 00161: val_loss did not improve from 1.44615
#
# Epoch 00162: val_loss improved from 1.44615 to 1.39754, saving model to weights.mlp.hdf5
#
# Epoch 00163: val_loss improved from 1.39754 to 1.37685, saving model to weights.mlp.hdf5
#
# Epoch 00164: val_loss did not improve from 1.37685
#
# Epoch 00165: val_loss improved from 1.37685 to 1.36806, saving model to weights.mlp.hdf5
#
# Epoch 00166: val_loss improved from 1.36806 to 1.35917, saving model to weights.mlp.hdf5
#
# Epoch 00167: val_loss did not improve from 1.35917
#
# Epoch 00168: val_loss did not improve from 1.35917
#
# Epoch 00169: val_loss did not improve from 1.35917
#
# Epoch 00170: val_loss did not improve from 1.35917
#
# Epoch 00171: val_loss improved from 1.35917 to 1.35189, saving model to weights.mlp.hdf5
#
# Epoch 00172: val_loss did not improve from 1.35189
#
# Epoch 00173: val_loss improved from 1.35189 to 1.32762, saving model to weights.mlp.hdf5
#
# Epoch 00174: val_loss improved from 1.32762 to 1.32743, saving model to weights.mlp.hdf5
#
# Epoch 00175: val_loss did not improve from 1.32743
#
# Epoch 00176: val_loss improved from 1.32743 to 1.32605, saving model to weights.mlp.hdf5
#
# Epoch 00177: val_loss improved from 1.32605 to 1.29901, saving model to weights.mlp.hdf5
#
# Epoch 00178: val_loss did not improve from 1.29901
#
# Epoch 00179: val_loss did not improve from 1.29901
#
# Epoch 00180: val_loss did not improve from 1.29901
#
# Epoch 00181: val_loss did not improve from 1.29901
#
# Epoch 00182: val_loss improved from 1.29901 to 1.28867, saving model to weights.mlp.hdf5
#
# Epoch 00183: val_loss improved from 1.28867 to 1.28711, saving model to weights.mlp.hdf5
#
# Epoch 00184: val_loss improved from 1.28711 to 1.27713, saving model to weights.mlp.hdf5
#
# Epoch 00185: val_loss did not improve from 1.27713
#
# Epoch 00186: val_loss improved from 1.27713 to 1.27170, saving model to weights.mlp.hdf5
#
# Epoch 00187: val_loss improved from 1.27170 to 1.26465, saving model to weights.mlp.hdf5
#
# Epoch 00188: val_loss improved from 1.26465 to 1.26175, saving model to weights.mlp.hdf5
#
# Epoch 00189: val_loss improved from 1.26175 to 1.24700, saving model to weights.mlp.hdf5
#
# Epoch 00190: val_loss did not improve from 1.24700
#
# Epoch 00191: val_loss did not improve from 1.24700
#
# Epoch 00192: val_loss did not improve from 1.24700
#
# Epoch 00193: val_loss did not improve from 1.24700
#
# Epoch 00194: val_loss did not improve from 1.24700
#
# Epoch 00195: val_loss improved from 1.24700 to 1.22814, saving model to weights.mlp.hdf5
#
# Epoch 00196: val_loss did not improve from 1.22814
#
# Epoch 00197: val_loss did not improve from 1.22814
#
# Epoch 00198: val_loss did not improve from 1.22814
#
# Epoch 00199: val_loss improved from 1.22814 to 1.22169, saving model to weights.mlp.hdf5
#
# Epoch 00200: val_loss improved from 1.22169 to 1.20922, saving model to weights.mlp.hdf5
#
# Epoch 00201: val_loss did not improve from 1.20922
#
# Epoch 00202: val_loss did not improve from 1.20922
#
# Epoch 00203: val_loss did not improve from 1.20922
#
# Epoch 00204: val_loss did not improve from 1.20922
#
# Epoch 00205: val_loss did not improve from 1.20922
#
# Epoch 00206: val_loss did not improve from 1.20922
#
# Epoch 00207: val_loss improved from 1.20922 to 1.20403, saving model to weights.mlp.hdf5
#
# Epoch 00208: val_loss did not improve from 1.20403
#
# Epoch 00209: val_loss did not improve from 1.20403
#
# Epoch 00210: val_loss did not improve from 1.20403
#
# Epoch 00211: val_loss did not improve from 1.20403
#
# Epoch 00212: val_loss did not improve from 1.20403
#
# Epoch 00213: val_loss did not improve from 1.20403
#
# Epoch 00214: val_loss did not improve from 1.20403
#
# Epoch 00215: val_loss improved from 1.20403 to 1.16753, saving model to weights.mlp.hdf5
#
# Epoch 00216: val_loss did not improve from 1.16753
#
# Epoch 00217: val_loss did not improve from 1.16753
#
# Epoch 00218: val_loss did not improve from 1.16753
#
# Epoch 00219: val_loss improved from 1.16753 to 1.15734, saving model to weights.mlp.hdf5
#
# Epoch 00220: val_loss did not improve from 1.15734
#
# Epoch 00221: val_loss did not improve from 1.15734
#
# Epoch 00222: val_loss did not improve from 1.15734
#
# Epoch 00223: val_loss did not improve from 1.15734
#
# Epoch 00224: val_loss did not improve from 1.15734
#
# Epoch 00225: val_loss did not improve from 1.15734
#
# Epoch 00226: val_loss did not improve from 1.15734
#
# Epoch 00227: val_loss did not improve from 1.15734
#
# Epoch 00228: val_loss did not improve from 1.15734
#
# Epoch 00229: val_loss improved from 1.15734 to 1.14143, saving model to weights.mlp.hdf5
#
# Epoch 00230: val_loss did not improve from 1.14143
#
# Epoch 00231: val_loss improved from 1.14143 to 1.13244, saving model to weights.mlp.hdf5
#
# Epoch 00232: val_loss did not improve from 1.13244
#
# Epoch 00233: val_loss did not improve from 1.13244
#
# Epoch 00234: val_loss did not improve from 1.13244
#
# Epoch 00235: val_loss improved from 1.13244 to 1.11748, saving model to weights.mlp.hdf5
#
# Epoch 00236: val_loss did not improve from 1.11748
#
# Epoch 00237: val_loss did not improve from 1.11748
#
# Epoch 00238: val_loss did not improve from 1.11748
#
# Epoch 00239: val_loss did not improve from 1.11748
#
# Epoch 00240: val_loss did not improve from 1.11748
#
# Epoch 00241: val_loss did not improve from 1.11748
#
# Epoch 00242: val_loss did not improve from 1.11748
#
# Epoch 00243: val_loss did not improve from 1.11748
#
# Epoch 00244: val_loss did not improve from 1.11748
#
# Epoch 00245: val_loss improved from 1.11748 to 1.10478, saving model to weights.mlp.hdf5
#
# Epoch 00246: val_loss did not improve from 1.10478
#
# Epoch 00247: val_loss did not improve from 1.10478
#
# Epoch 00248: val_loss did not improve from 1.10478
#
# Epoch 00249: val_loss did not improve from 1.10478
#
# Epoch 00250: val_loss did not improve from 1.10478
#
# Epoch 00251: val_loss did not improve from 1.10478
#
# Epoch 00252: val_loss did not improve from 1.10478
#
# Epoch 00253: val_loss did not improve from 1.10478
#
# Epoch 00254: val_loss did not improve from 1.10478
#
# Epoch 00255: val_loss did not improve from 1.10478
#
# Epoch 00256: val_loss did not improve from 1.10478
#
# Epoch 00257: val_loss did not improve from 1.10478
#
# Epoch 00258: val_loss improved from 1.10478 to 1.10356, saving model to weights.mlp.hdf5
#
# Epoch 00259: val_loss improved from 1.10356 to 1.09473, saving model to weights.mlp.hdf5
#
# Epoch 00260: val_loss did not improve from 1.09473
#
# Epoch 00261: val_loss did not improve from 1.09473
#
# Epoch 00262: val_loss did not improve from 1.09473
#
# Epoch 00263: val_loss did not improve from 1.09473
#
# Epoch 00264: val_loss did not improve from 1.09473
#
# Epoch 00265: val_loss did not improve from 1.09473
#
# Epoch 00266: val_loss did not improve from 1.09473
#
# Epoch 00267: val_loss did not improve from 1.09473
#
# Epoch 00268: val_loss did not improve from 1.09473
#
# Epoch 00269: val_loss improved from 1.09473 to 1.09157, saving model to weights.mlp.hdf5
#
# Epoch 00270: val_loss did not improve from 1.09157
#
# Epoch 00271: val_loss did not improve from 1.09157
#
# Epoch 00272: val_loss did not improve from 1.09157
#
# Epoch 00273: val_loss did not improve from 1.09157
#
# Epoch 00274: val_loss did not improve from 1.09157
#
# Epoch 00275: val_loss did not improve from 1.09157
#
# Epoch 00276: val_loss did not improve from 1.09157
#
# Epoch 00277: val_loss did not improve from 1.09157
#
# Epoch 00278: val_loss did not improve from 1.09157
#
# Epoch 00279: val_loss did not improve from 1.09157
#
# Epoch 00280: val_loss did not improve from 1.09157
#
# Epoch 00281: val_loss did not improve from 1.09157
#
# Epoch 00282: val_loss did not improve from 1.09157
#
# Epoch 00283: val_loss did not improve from 1.09157
#
# Epoch 00284: val_loss did not improve from 1.09157
#
# Epoch 00285: val_loss did not improve from 1.09157
#
# Epoch 00286: val_loss did not improve from 1.09157
#
# Epoch 00287: val_loss did not improve from 1.09157
#
# Epoch 00288: val_loss did not improve from 1.09157
#
# Epoch 00289: val_loss did not improve from 1.09157
#
# Epoch 00290: val_loss did not improve from 1.09157
#
# Epoch 00291: val_loss did not improve from 1.09157
#
# Epoch 00292: val_loss did not improve from 1.09157
#
# Epoch 00293: val_loss did not improve from 1.09157
#
# Epoch 00294: val_loss did not improve from 1.09157
#
# Epoch 00295: val_loss improved from 1.09157 to 1.08860, saving model to weights.mlp.hdf5
#
# Epoch 00296: val_loss did not improve from 1.08860
#
# Epoch 00297: val_loss did not improve from 1.08860
#
# Epoch 00298: val_loss did not improve from 1.08860
#
# Epoch 00299: val_loss did not improve from 1.08860
#
# Epoch 00300: val_loss did not improve from 1.08860

# %%
x_plot = list(range(1,301))

def plot_history(network_history):
  plt.figure()
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.plot(x_plot, network_history.history['loss'])
  plt.plot(x_plot, network_history.history['val_loss'])
  plt.legend(['Training', 'Validation'])
  plt.figure()
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.plot(x_plot, network_history.history['accuracy'])
  plt.plot(x_plot, network_history.history['val_accuracy'])
  plt.legend(['Training', 'Validation'], loc='lower right')
  plt.show()

plot_history(model_history)

# %%
score = mlp.evaluate(x_test, y_test, batch_size=16)

score
# Out:
# 5/5 [==============================] - 0s 17ms/step - loss: 1.1390 - accuracy: 0.6623
# [1.1390434503555298, 0.6623376607894897]
